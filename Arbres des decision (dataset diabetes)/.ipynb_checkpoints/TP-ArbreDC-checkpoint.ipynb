# %% [markdown]
# # TP Arbres des decision :

# %% [markdown]
# #### Exercice N°1 : Prédictions des diabètes

# %% [markdown]
# Nous allons voir un exemple de mise en œuvre d'un classificateur 'arbre de décision'
# pour le problème du
# diabète.
#
# L'objectif est de prédire sur la base de mesures diagnostiques si un patient est atteint de diabète ou
# non.
#
# Nous construisons un modèle qui va faire des prédictions, nous devons donc trouver un moyen d'évaluer la
# qualité de ces prédictions. Étant donné que les prédictions par définition ne concernent que des données
# inédites,
# nous ne pouvons pas dépendre des données utilisées pour évaluer le modèle. Nous avons pour
# cela diviser le jeu de données en deux parties non croisées.

# %% [markdown]
# 1. Importer les bibliothèques nécessaires pour l’algorithme Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression 
from sklearn import tree
from sklearn.metrics import confusion_matrix , accuracy_score

# %%
dataf = pd.read_csv("diabetes.csv")
x = dataf.iloc[ : , :-1]
y = dataf.iloc[ : , -1]
dataf.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , train_size=0.75)
print("x_train shape = {}\nx_test shape = {}\ny_train shape = {}\ny_test shape = {}".format(x_train.shape , x_test.shape , y_train.shape , y_test.shape))
# Out:
# x_train shape = (576, 8)
# x_test shape = (192, 8)
# y_train shape = (576,)
# y_test shape = (192,)

# %% [markdown]
# - visualiser notre variable cible (y)

# %%
sns.countplot(x=dataf.Outcome)
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='count'>

# %% [markdown]
# - La matrice de Correlation : pour illistrer l'impact de chaque Caractere sur notre target "Outcome"

# %%
plt.figure(figsize=(16 ,10))
sns.heatmap(dataf.corr() , annot=True , cmap="Blues")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### 2. Nous utilisons l'ensemble d'entrainement pour construire notre modèle pour les arbres de decision.

# %%
model = DecisionTreeClassifier(max_depth = 2)
model
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
fitting = model.fit(x_train , y_train)

# %% [markdown]
# 3. Évaluer son score sur l'ensemble de test.

# %%
pred = fitting.predict(x_test)

# %% [markdown]
# 4. Calculer la matrice de confusion et l’accuracy score, Comparer les résultats obtenus entre
# l’algorithme de la régression Logistique et Les arbres de Decision.

# %%
conf = confusion_matrix(y_test , pred )
print("La matrice de defusion associe a L'arbre de decision : \n " , conf)
# Out:
# La matrice de defusion associe a L'arbre de decision :
#   [[110  18]
#  [ 28  36]]

# %%
accy = accuracy_score(y_test , pred)
print("Le score de L'arbre de decision : \n " , accy)
# Out:
# Le score de L'arbre de decision :
#   0.7604166666666666

# %% [markdown]
# 5. Afficher la matrice de confusion, comparer les résultats entre les deux algorithmes.

# %%
import seaborn as sns
sns.heatmap(conf , annot= True )
# Out:
# <AxesSubplot: >

# %% [markdown]
# On a dans le modele du regression Logistique une score de 0.86 ,
#
# ce score es grande par apport a le score de le modele de arbre de decision .
#
# donc , l'agorithme le plus performant est l'algorithme de la regression Logistique

# %% [markdown]
# 6. Quel algorithme est performant en termes de prédiction.

# %% [markdown]
# #### Algorithme de La regression Logistique

# %% [markdown]
# 7. Visualiser l’arbres de décision

# %% [markdown]
# - Arbre avec une seule phase : (max_depth = 1)

# %%
tree.plot_tree(fitting , filled=True , max_depth=1)
# Out:
# [Text(0.5, 0.8333333333333334, 'X[1] <= 127.5\ngini = 0.457\nsamples = 576\nvalue = [372, 204]'),
#  Text(0.25, 0.5, 'X[5] <= 26.45\ngini = 0.317\nsamples = 364\nvalue = [292, 72]'),
#  Text(0.125, 0.16666666666666666, '\n  (...)  \n'),
#  Text(0.375, 0.16666666666666666, '\n  (...)  \n'),
#  Text(0.75, 0.5, 'X[5] <= 29.95\ngini = 0.47\nsamples = 212\nvalue = [80, 132]'),
#  Text(0.625, 0.16666666666666666, '\n  (...)  \n'),
#  Text(0.875, 0.16666666666666666, '\n  (...)  \n')]

# %% [markdown]
# - Visualiser la totalite d'Arbre (tous les phases)

# %%
fig = plt.figure(figsize=(30 ,30))
tree.plot_tree(fitting , feature_names=x.values , class_names=["0" ,"1"] , filled=True)
plt.title("Decision tree for diaberts dataset")
plt.show()

# %% [markdown]
# # FIN.
